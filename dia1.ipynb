# %%
#VARIABLES 

fruta = 'naranja'
print(fruta)
 
cantidadDeFrutas = 4
print(cantidadDeFrutas)
 
fruta = 'banana'
print(fruta)

#TIPOS DE DATOS 

edad=28 #Integer (int) numeros enteros 
altura = 1.80 # numero flotante (float)
nombre = 'Arturo' # string 
feliz = False # Dato booleanos (True o False)

print(edad, altura, nombre, feliz)
# Out:
# naranja
# 4
# banana
# 28 1.8 Arturo False

# %%
# PRIMER CHALLENGE 
nombre = 'Arturo' # String 
edad = 20 # Int
ciudad = 'Luque' # String 

print ("Hola me llamo", nombre,"tengo", edad, "vivo en la ciudad de",ciudad) # imprimir
# Out:
# Hola me llamo, Arturo tengo 20 vivo en la ciudad de Luque

# %%
# Operadores aritmeticos 
producto1=

# %%
# 2do CHALLENGE 
cantidad_de_manzanas= 35
cantidad_de_naranjas= 20 
cantidad_de_frutas= cantidad_de_manzanas + cantidad_de_naranjas
print(cantidad_de_frutas)

frutas_vendidas= 30 
frutas_restantes= cantidad_de_frutas - frutas_vendidas
print(frutas_restantes)
# Out:
# 55
# 25

# %%
# CONCATENAR LOS STRINGS
    #variables
nombre= 'Arturo'
apellido= 'Colman'

print(nombre)
print(apellido)

print (f'Hola me llamo {nombre}, y mi apellido es {apellido}')
# Out:
# Arturo
# Colman
# Hola me llamo Arturo, y mi apellido es Colman

# %%
#3 CHALLENGE 

#Resolucion de problema 
nombre= 'Alan'
apellido= ' Nuñez'

print(f' Hola, me llamo {nombre + apellido}, mucho gusto. ')
# Out:
#  Hola, me llamo Alan Nuñez, mucho gusto.

# %%
nombre= input("Escribe tu nombre")
print(nombre)

# %%
producto= input('Que producto deseas')
print(producto)
# Out:
# lol

# %%
nombre= input('como te llamas')
print(type,{nombre})
# Out:
# <class 'type'> {'str'}

# %%
#Aqui ingrese el primer numero y lo guarde en mi variable "Num1"
numero1= input('Ingresa un numero')
num1= int(numero1)
print(num1)

#Aqui ingrese el segundo numero y lo guarde en mi variable "Num1"
numero2= input('ingresa un segundo numero')
num2= int (numero2)
print(num2)

suma= num1 + num2
print( "El resultado de los dos numeros es",suma)
# Out:
# 6
# 7
# El resultado de los dos numeros es 13

# %%
# Acadefinimos la funcion 
def preparar_sandwich():
    print('Preparar sandwich')
    print('comer el sandwich')
    #Aqui termina lafuncion 
    
# Aqui llamamos a la funcion 
preparar_sandwich()
# Out:
# Preparar sandwich
# comer el sandwich

# %%
#4 CHALLENGE

# Esta es la funcion de barrer la casa. 
def barrer_la_casa():
    print('Tomar la escoba')
    print('Barrer')
    print('Tomar la palita')
    print('Tirar la basura\n')
# Culmino la funcion. 

# Aqui ejecuto 3 veces la misma funcion."BARRER LA CASA"
barrer_la_casa()

barrer_la_casa()

barrer_la_casa()
# Out:
# Tomar la escoba
# Barrer
# Tomar la palita
# Tirar la basura
#
# Tomar la escoba
# Barrer
# Tomar la palita
# Tirar la basura
#
# Tomar la escoba
# Barrer
# Tomar la palita
# Tirar la basura

# %%
# Aqui le pido al usuario que me de dos numeros Int y luego las guardo dentro del arvhivo variable. (challenge nro 3)
numero_one= int(input('Me das un primer numero'))
numero_two= int(input('Me das un segundo numero'))

# Aqui imprimo los dos numeros que me pide y el tipo de DATO que es.
print(numero_one)
print(type(numero_one))
print(numero_two)
print(type(numero_two))

# Aqui realizo la suma de los dos numeros.
suma= numero_one + numero_two
print(" El resultado es: ", suma)
# Out:
# 5
# <class 'int'>
# 8
# <class 'int'>
#  El resultado es:  13

# %%
caracteristica1= input("Dame el color la escoba")
caracteristica2= input("Dame la marca de la escoba")
print("Color:",caracteristica1 + " " + "Marca:", caracteristica2)

color= 'Amarillo'
marca= 'Arbol de guayaba'

def producto(caracteristica1, caracteristica2): 
    print (input("muestrame las caracteristicas del {producto} prodcuto."))
producto(caracteristica1, caracteristica2)
# Out:
# Color: AMA Marca: arbol
# Marca

# %%
def producto(caract1, caract2, caract3):
    caract1=()

    
    
    print(caract1, caract2, caract3)
