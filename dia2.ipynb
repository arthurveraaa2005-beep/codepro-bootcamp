# %%
# Solucion
# Preguntar al usuario 
edad= int(input('edad del usuario'))

# %%
temperatura= int(input('Cual es el grado Celsius?'))
print('la temperaturs es de',temperatura)

#Condicionales. 
if temperatura >= -10 and temperatura <= 18:
    print('fresquete')
elif temperatura >= 19 and temperatura <= 30: 
    print('calor`i')
elif temperatura >= 31 and temperatura <= 45:
    print('hakuuuu')
else:
    print('moriremos mba`e')
# Out:
# la temperaturs es de 46
# moriremos mba`e

# %%
#Escribir un programa que alamacene una variab
contra=input('Ingrese sucontranha')
print('milanesa')
while True:
# Out:
# milanesa

# %%
lista_compras=('hamburguesa', 'huevo', 'tomate', 'cheddar', 'pan')
print(lista_compras)
# Out:
# ('hamburguesa', 'huevo', 'tomate', 'cheddar', 'pan')

# %%
for i in range(10):
    i= i*2
    print('tengo hambre',i)
# Out:
# tengo hambre 0
# tengo hambre 2
# tengo hambre 4
# tengo hambre 6
# tengo hambre 8
# tengo hambre 10
# tengo hambre 12
# tengo hambre 14
# tengo hambre 16
# tengo hambre 18

# %%
marcas=['Yamaha','toyota','suzuki']
for marca in marcas:
len(marca) >= 6:
print(marcas")
# Out:
#   Cell In[79], line 3
#     len(marcas) >= 6:
#     ^
# IndentationError: expected an indented block after 'for' statement on line 2

# %%
usuario= input('Dame una frase')

# %%
# Variables
palabra_secreta= 'gordo'

#Tipos de datos 
datos_bool= True #Booleanos
datos_integer= 20 #Integer
Datos_flotante= 2.59 #Flotantes
datos_string='Hola' #String
datos_string1= 'Chau' #String

# %%
#Operadores logicos: 
# +,-,*,/,//,resto 
letra1= "a"
letra2= "b"
letras_son_iguales= letra1 == letra2
print (letras_son_iguales)

letra_existe_en_la_palabra= letra1 in palabra_secreta
print(letra_existe_en_la_palabra)
# Out:
# False
# False
