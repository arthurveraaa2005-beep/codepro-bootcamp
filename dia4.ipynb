# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# ## Diccionarios
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario.
#
# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# %%
# Crear un diccionario vacio 
#datos= input('Dame info de una persona con estos datos: Nombre, Apellido, Gmail, Celular')
#print(datos)
d1= {}
print(d1)
d1['Nombre:'] = input('Ingrese nombre')
print(d1)
d1['Apellido'] = input('Ingrese Aoellido')
print(d1)
d1['Edad'] = int(input('Ingrese edad'))
print(d1)
d1['Gmail'] = input('Ingrese Gmail')
print(d1)
d1['Telefono'] = input('Ingresa Telefono')
print(d1)
# Out:
# {}
# {'Nombre:': 'Arturo'}
# {'Nombre:': 'Arturo', 'Apellido': 'Colman'}
# {'Nombre:': 'Arturo', 'Apellido': 'Colman', 'Edad': 20}
# {'Nombre:': 'Arturo', 'Apellido': 'Colman', 'Edad': 20, 'Gmail': 'arthurveraaa2005@gmail.com'}
# {'Nombre:': 'Arturo', 'Apellido': 'Colman', 'Edad': 20, 'Gmail': 'arthurveraaa2005@gmail.com', 'Telefono': '099999999'}

# %% [markdown]
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
# Primero creamos un diccionario
diccionario= {}
print({})

diccionario['Nombre'] = input('nombre del user')
print(diccionario)
diccionario['Cargo'] = input('Cargo del user')
print(diccionario)
# Condiciones
if dato in diccionario
    print('Ingresa el numero de usuario')

# %% [markdown]
# 1# Crear una tarjeta personal (nombre,cargo,gmail)
# 2# El usuario puede elegir mediante un input si quiere crear, modificar, eliminar.

# %%
agenda_contactos= {}
print(agenda_contactos)

while True:
    metodos= int(input('Desea: 1=Mostrar, 2:crear, :Modificar'))
    if

# %% [markdown]
# ## programacion orientadas a objetos
# python tambien nos permite representar cosasdel mundo real, mas

# %%
# Molde de objeto 
class Perro:
    #Atributos de clase
    cabeza= 1 
    patas= 4
    cola= 1

    # Creando objeto -- Instancia un objeto 
firulais= Perro()
choco= Perro()

print(firulais.cabeza)
print(choco.patas)
# Out:
# 1
# 4

# %%
# Molde
class Perro:
    #Atributos de clase 
    especie = "canina"

    def _init_(self,nombre,raza,color):
        self.nombre = nombre 
        self.raza = raza 
        self.color = color 

# Crear el objeto 
firulais= Perro('Firulais','Mestizo','Marron')
print(firulais.raza)

# %% [markdown]
# ## Definiendo atributos
# Atributos declase
# atributos de instancia

# %%
# Crear el molde del objeto
class Mitos:
    # Tiene que ir indentado
    especie = 'extraterrestre'

    # Atributos de clase
    cabeza = 3
    patas = 4
    colas = 3

    # Atributos de instancia
    nombre= 'king Gidora'
    color= 'Dorado'

    def _init_(self, nombre, color):
        self.nombre= nombre
        self.color= color
    print(f'Me llamo {nombre}, y soy de color {color}')
# Out:
# Me llamo king Gidora, y soy de color Dorado

# %% [markdown]
# ## Definiendo metodoss

# %%
class superHeroe:
    # Atributo de clase 
    especie = 'Super Humanps'

    # Definir metodo constructor para definir sus atributos de instancias
    def _init_(self, nombre):
        self,nombre = nombre
    # Metodo 
    def rayos_laser(self):
        print('Tiro rayos laseres')
    def volar(self,km):
        print(f'Estoy volando a {km} km')

    def alzar_objetos(self,objeto,kg):
        print(f'Puedo alzar un {objeto} de {kg} kg')

    #Instancias de objetos 
    superheroe1= superHeroe('Batman')
    superheroe1.volar

# %%
class Coche: 
    tipo = 'Vehiculo'

    # Atributos de instancia 
    def _init_(self,modelo,posicion = 0):
        self.modelo = modelo
        self.posicion = posicion 

    # Definir otras acciones de la clase 
    def acelerar(self,metros):
        self.posicion += metros 
        print(f"El vehiculo modelo {self.modelo} acelera y avanza {metros}. Nueva posicio: {self.posicion}")
    def girar(self,direccion):
        print(f"El {self.modelo} avanza y gira a la {direccion} direccion")

coche1= Coche('taiga')
coche1.girar('a la izquierda')

# %%
class Gato:
    especie = 'Gato'

    def _init_(self,jugar,caminar):

    def caminar(self,caminar):
        print(f'Mi gato {self.caminar}')
    
    def jugar(self,saltar):
        print(f'Mi gato {self.saltar} cuando me ve')

mi_gato.jugar('camina hacia mi')
# Out:
#   Cell In[6], line 6
#     def caminar(self,caminar):
#     ^
# IndentationError: expected an indented block after function definition on line 4

# %%
class animalDeGranja:
    # Atributos de clase 
    tipo = " animal de granja"

    # Atributos de instancia 
    def _init_(self, nombre,color,sonido):
        self.nombre= nombre
        self.color = color
        self.sonido = sonido 

    # Meodos ( Acciones de clase
    def hablar(self):
        print(f'Hablo y digo {self.sonido}')

    def presentarse(self):
        print(f'Hols, soy {self.nombre}')

class Gallina(animalDeGranja):
    huevos_por_dia = 1

    def poner_huevo(self):
        print(f'Estoy poniendo {self.huevos_por_dia} huevos por dia')

class Vaca(Gallina):
    patas = 4

    def mujir(self):
        print('muuuu')
    gallina1 = Gallina("Hortencia","marron", "corococo"):
    gallina1.hablar()
# Out:
#   Cell In[7], line 29
#     gallina1 = Gallina("Hortencia","marron", "corococo"):
#                                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class Madre:
    # Instancia de clase
    clase = 'Madre'
    # Atributos de insgtancia 
    def __init__(self,nombre,apellido):
        self.nombre = nombre
        self.apellido = apellido 
# Acciones
class Hijas(Madre):
    def saludar(self):
        print(f'Hola, mucho gusto, mi nombre es {self.nombre} y mi apellido es {self.apellido}')
    def preguntar(self):
        print('Donde queda esta ubicacion?')

hija1= Hijas('Maria','Escobar')
hija1.saludar()
hija1.preguntar()

hija2= Hijas('Laura','Escobar')
hija2.saludar()
hija2.preguntar()
# Out:
# Hola, mucho gusto, mi nombre es Maria y mi apellido es Escobar
# Donde queda esta ubicacion?
# Hola, mucho gusto, mi nombre es Laura y mi apellido es Escobar
# Donde queda esta ubicacion?

# %% [markdown]
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
nombre = 'Luffy'
poder = "ser hombre de goma"
nombre = 'Doflamingo'
poder= 'Hilo'
class SuperHumano:
    def __init__(self,nombre,poder):
        self.nombre = nombre
        self.poder = poder
class Heroe(SuperHumano):

    # Acciones
    def presentarse1(self, nombre, poder):
        print(f'Hola mi nombre es {nombre} y mi poder es {poder} jejejeje ')

class Villano(SuperHumano):

    def presentarse2(self, nombre, poder):
        print(f'Hola mi nombre es {nombre} y mi poder es {poder} jijijijjiji ')


heroe1= Heroe("luffy","Hombre de goma")
heroe1.presentarse1(nombre,poder)



villano= Villano("Doflamingo","Hilo")
villano.presentarse2(nombre,poder)
# Out:
# Hola mi nombre es Doflamingo y mi poder es Hilo jejejeje
# Hola mi nombre es Doflamingo y mi poder es Hilo jijijijjiji
